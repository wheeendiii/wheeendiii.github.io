# %%
import pandas as pd

# %% [markdown]
# ## Import the dataset

# %%
buildings = pd.read_csv('building_inventory.csv')
buildings.head(10)
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
# 5  Department of Natural Resources
# 6  Department of Natural Resources
# 7  Department of Natural Resources
# 8  Department of Natural Resources
# 9  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 5  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 6           Dixon Springs State Park - Pope County               Rr #2
# 7           Dixon Springs State Park - Pope County               Rr #2
# 8          Matthiessen State Park - LaSalle County  R. R. 178, Box 509
# 9          Matthiessen State Park - LaSalle County  R. R. 178, Box 509
#
#        City  Zip code   County  Congress Dist Congressional Full Name  \
# 0   Astoria     61501   Fulton             17            Cheri Bustos
# 1   Astoria     61501   Fulton             17            Cheri Bustos
# 2   Astoria     61501   Fulton             17            Cheri Bustos
# 3   Astoria     61501   Fulton             17            Cheri Bustos
# 4   Astoria     61501   Fulton             17            Cheri Bustos
# 5   Astoria     61501   Fulton             17            Cheri Bustos
# 6  Golconda     62938     Pope             15            John Shimkus
# 7  Golconda     62938     Pope             15            John Shimkus
# 8     Utica     61373  LaSalle             16          Adam Kinzinger
# 9     Utica     61373  LaSalle             16          Adam Kinzinger
#
#    Rep Dist      Rep Full Name  ...  Bldg Status Year Acquired  \
# 0        93  Hammond Norine K.  ...       In Use          1975
# 1        93  Hammond Norine K.  ...       In Use          2004
# 2        93  Hammond Norine K.  ...       In Use          2004
# 3        93  Hammond Norine K.  ...       In Use          2004
# 4        93  Hammond Norine K.  ...       In Use          2004
# 5        93  Hammond Norine K.  ...       In Use          2004
# 6       118  Phelps Brandon W.  ...       In Use          2000
# 7       118  Phelps Brandon W.  ...       In Use          2000
# 8        76     Long Jerry Lee  ...       In Use          2000
# 9        76     Long Jerry Lee  ...       In Use          2000
#
#   Year Constructed  Square Footage  Total Floors  Floors Above Grade  \
# 0             1975             144             1                   1
# 1             2004             144             1                   1
# 2             2004             144             1                   1
# 3             2004             144             1                   1
# 4             2004             144             1                   1
# 5             2004             144             1                   1
# 6             2000             120             1                   1
# 7             2000             120             1                   1
# 8             2000             144             1                   1
# 9             2000             144             1                   1
#
#    Floors Below Grade  Usage Description  Usage Description 2  \
# 0                   0            Unusual              Unusual
# 1                   0            Unusual              Unusual
# 2                   0            Unusual              Unusual
# 3                   0            Unusual              Unusual
# 4                   0            Unusual              Unusual
# 5                   0            Unusual              Unusual
# 6                   0            Unusual              Unusual
# 7                   0            Unusual              Unusual
# 8                   0            Unusual              Unusual
# 9                   0            Unusual              Unusual
#
#   Usage Description 3
# 0        Not provided
# 1        Not provided
# 2        Not provided
# 3        Not provided
# 4        Not provided
# 5        Not provided
# 6        Not provided
# 7        Not provided
# 8        Not provided
# 9        Not provided
#
# [10 rows x 22 columns]

# %% [markdown]
# #### Relationship between the year acquired and the year constructed

# %%
buildings.plot(x="Year Acquired", y="Year Constructed",figsize=(10,6),kind='scatter')

# %% [markdown]
# On default, the graph generated a line plot and it displayed a rectangle pattern. The graph did not show any relationship between these two variables so I plotted a scatter plot instead. Then I noticed four clusters based on the result. Each case represents a different scenario. We can see that in most cases, buildings are acquired in a year after construction. (top right corner) Top left corner represents a few ongoing constructions where year acquired is 0. Bottom left data points shows that both year constructed and year acquired are missing. Bottom right points represents buildings whose year constructed information is missing.  Although we can see the four types of relationships between the two variables, one drawback is that we cannot obtain the exact information of each data point from this plot.

# %% [markdown]
# #### Total square footage as a function of congressional district

# %%
re_dist = buildings.groupby("Congress Dist")["Square Footage"].sum()
re_dist.plot(figsize=(10,6))

# %% [markdown]
# 1.try normal
# 2. groupby
# 3.  try adding x and y in the plot function
# Intuitively, we should use "nominal" since the "Congress Dist" is categorical data. However, when I change the type of x from quantitative to nominal , the rank of x would be in a mess. It looks like the Javascript treats nominal data as string in sort so the rank would be "0,1,10,11……" rather than  "0,1,2,3……"

# %% [markdown]
# #### Average square footage per floor as a function of congressional district

# %%
buildings['Average Square Footage'] = buildings['Square Footage']/buildings['Total Floors']
av_dist = buildings.groupby("Congress Dist")["Average Square Footage"].sum()
av_dist.plot(figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-515a18d6a140> in <module>
# ----> 1 buildings['Average Square Footage'] = buildings['Square Footage']/buildings['Total Floors']
#       2 av_dist = buildings.groupby("Congress Dist")["Average Square Footage"].sum()
#       3 av_dist.plot(figsize=(10,6))
#
# NameError: name 'buildings' is not defined
